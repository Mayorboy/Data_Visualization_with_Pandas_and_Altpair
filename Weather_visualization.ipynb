# %%
import pandas as pd

url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"
data = pd.read_csv(url_prefix + "tromso-daily.csv")

data
# Out:
#                  name  station        date  max temperature  min temperature  \
# 0    Tromso - Langnes  SN90490  09.10.2022              6.9              4.7
# 1    Tromso - Langnes  SN90490  10.10.2022              9.5              5.1
# 2    Tromso - Langnes  SN90490  11.10.2022             10.7              4.5
# 3    Tromso - Langnes  SN90490  12.10.2022              7.2              3.5
# 4    Tromso - Langnes  SN90490  13.10.2022              8.2              4.2
# ..                ...      ...         ...              ...              ...
# 361  Tromso - Langnes  SN90490  05.10.2023              3.9              1.4
# 362  Tromso - Langnes  SN90490  06.10.2023              3.0              0.2
# 363  Tromso - Langnes  SN90490  07.10.2023              2.5             -0.6
# 364  Tromso - Langnes  SN90490  08.10.2023              4.0              0.8
# 365  Tromso - Langnes  SN90490  09.10.2023              3.7              1.1
#
#      snow depth  precipitation
# 0             0           20.0
# 1             0            8.3
# 2             0            3.0
# 3             0            6.0
# 4             0           18.0
# ..          ...            ...
# 361           0            5.4
# 362           0           20.3
# 363           0           13.5
# 364           0            9.0
# 365           0            3.0
#
# [366 rows x 7 columns]

# %%
data.head()
# Out:
#                name  station        date  max temperature  min temperature  \
# 0  Tromso - Langnes  SN90490  09.10.2022              6.9              4.7
# 1  Tromso - Langnes  SN90490  10.10.2022              9.5              5.1
# 2  Tromso - Langnes  SN90490  11.10.2022             10.7              4.5
# 3  Tromso - Langnes  SN90490  12.10.2022              7.2              3.5
# 4  Tromso - Langnes  SN90490  13.10.2022              8.2              4.2
#
#    snow depth  precipitation
# 0           0           20.0
# 1           0            8.3
# 2           0            3.0
# 3           0            6.0
# 4           0           18.0

# %%
data.columns
# Out:
# Index(['name', 'station', 'date', 'max temperature', 'min temperature',
#        'snow depth', 'precipitation'],
#       dtype='object')

# %%
data.dtypes
# Out:
# name                object
# station             object
# date                object
# max temperature    float64
# min temperature    float64
# snow depth           int64
# precipitation      float64
# dtype: object

# %%
# we don't need to import again but just in case you started here
import pandas as pd

url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"

data_tromso = pd.read_csv(url_prefix + "tromso-monthly.csv")
data_oslo = pd.read_csv(url_prefix + "oslo-monthly.csv")

data = pd.concat([data_tromso, data_oslo], axis=0)

# let us print the combined result
data
# Out:
#                 name  station     date  max temperature  precipitation  \
# 0   Tromso - Langnes  SN90490  10.2022             10.7          187.0
# 1   Tromso - Langnes  SN90490  11.2022              8.5           41.5
# 2   Tromso - Langnes  SN90490  12.2022              5.6           88.8
# 3   Tromso - Langnes  SN90490   1.2023              7.7          111.4
# 4   Tromso - Langnes  SN90490   2.2023              6.6          171.3
# 5   Tromso - Langnes  SN90490   3.2023              4.5          157.0
# 6   Tromso - Langnes  SN90490   4.2023              9.8           85.0
# 7   Tromso - Langnes  SN90490   5.2023             17.7          101.2
# 8   Tromso - Langnes  SN90490   6.2023             25.4           43.4
# 9   Tromso - Langnes  SN90490   7.2023             26.7           14.0
# 10  Tromso - Langnes  SN90490   8.2023             25.1           43.4
# 11  Tromso - Langnes  SN90490   9.2023             19.3          163.7
# 12  Tromso - Langnes  SN90490  10.2023              9.8           64.8
# 0    Oslo - Blindern  SN18700  10.2022             17.1           82.9
# 1    Oslo - Blindern  SN18700  11.2022             15.1           83.4
# 2    Oslo - Blindern  SN18700  12.2022              6.5           85.5
# 3    Oslo - Blindern  SN18700   1.2023              7.2          100.5
# 4    Oslo - Blindern  SN18700   2.2023             10.2           46.0
# 5    Oslo - Blindern  SN18700   3.2023              9.8           72.6
# 6    Oslo - Blindern  SN18700   4.2023             19.8           99.7
# 7    Oslo - Blindern  SN18700   5.2023             24.2           17.0
# 8    Oslo - Blindern  SN18700   6.2023             31.8           39.9
# 9    Oslo - Blindern  SN18700   7.2023             28.4          146.9
# 10   Oslo - Blindern  SN18700   8.2023             24.5          259.8
# 11   Oslo - Blindern  SN18700   9.2023             25.1          105.8
# 12   Oslo - Blindern  SN18700  10.2023             17.1            7.3
#
#     min temperature
# 0              -4.2
# 1              -7.0
# 2             -11.7
# 3             -13.9
# 4             -10.7
# 5             -15.1
# 6              -7.1
# 7              -4.6
# 8              -0.4
# 9               6.0
# 10              5.4
# 11              0.3
# 12             -0.6
# 0              -0.4
# 1              -2.1
# 2             -14.6
# 3             -13.4
# 4              -9.4
# 5             -12.6
# 6              -4.7
# 7              -0.8
# 8               4.6
# 9               8.6
# 10              9.8
# 11              5.3
# 12             -0.7

# %%
data
# Out:
#                 name  station     date  max temperature  precipitation  \
# 0   Tromso - Langnes  SN90490  10.2022             10.7          187.0
# 1   Tromso - Langnes  SN90490  11.2022              8.5           41.5
# 2   Tromso - Langnes  SN90490  12.2022              5.6           88.8
# 3   Tromso - Langnes  SN90490   1.2023              7.7          111.4
# 4   Tromso - Langnes  SN90490   2.2023              6.6          171.3
# 5   Tromso - Langnes  SN90490   3.2023              4.5          157.0
# 6   Tromso - Langnes  SN90490   4.2023              9.8           85.0
# 7   Tromso - Langnes  SN90490   5.2023             17.7          101.2
# 8   Tromso - Langnes  SN90490   6.2023             25.4           43.4
# 9   Tromso - Langnes  SN90490   7.2023             26.7           14.0
# 10  Tromso - Langnes  SN90490   8.2023             25.1           43.4
# 11  Tromso - Langnes  SN90490   9.2023             19.3          163.7
# 12  Tromso - Langnes  SN90490  10.2023              9.8           64.8
# 0    Oslo - Blindern  SN18700  10.2022             17.1           82.9
# 1    Oslo - Blindern  SN18700  11.2022             15.1           83.4
# 2    Oslo - Blindern  SN18700  12.2022              6.5           85.5
# 3    Oslo - Blindern  SN18700   1.2023              7.2          100.5
# 4    Oslo - Blindern  SN18700   2.2023             10.2           46.0
# 5    Oslo - Blindern  SN18700   3.2023              9.8           72.6
# 6    Oslo - Blindern  SN18700   4.2023             19.8           99.7
# 7    Oslo - Blindern  SN18700   5.2023             24.2           17.0
# 8    Oslo - Blindern  SN18700   6.2023             31.8           39.9
# 9    Oslo - Blindern  SN18700   7.2023             28.4          146.9
# 10   Oslo - Blindern  SN18700   8.2023             24.5          259.8
# 11   Oslo - Blindern  SN18700   9.2023             25.1          105.8
# 12   Oslo - Blindern  SN18700  10.2023             17.1            7.3
#
#     min temperature
# 0              -4.2
# 1              -7.0
# 2             -11.7
# 3             -13.9
# 4             -10.7
# 5             -15.1
# 6              -7.1
# 7              -4.6
# 8              -0.4
# 9               6.0
# 10              5.4
# 11              0.3
# 12             -0.6
# 0              -0.4
# 1              -2.1
# 2             -14.6
# 3             -13.4
# 4              -9.4
# 5             -12.6
# 6              -4.7
# 7              -0.8
# 8               4.6
# 9               8.6
# 10              9.8
# 11              5.3
# 12             -0.7

# %%
import altair as alt

alt.Chart(data).mark_bar().encode(
    x="date",
    y="precipitation",
    color="name",
    column = "date",
    )
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
from PIL import Image
from IPython.display import display
img = Image.open('precipitation.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=4330x395>

# %%
alt.Chart(data).mark_area(opacity=0.5).encode(
    x="date",
    y="max temperature",
    y2="min temperature",
    color="name",
    row="name",
    )
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
from PIL import Image
from IPython.display import display
img = Image.open('temp.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=517x670>

# %%
url_prefix = "https://raw.githubusercontent.com/coderefinery/data-visualization-python/main/data/"

data_tromso = pd.read_csv(url_prefix + "tromso-daily.csv")
data_oslo = pd.read_csv(url_prefix + "oslo-daily.csv")

data = pd.concat([data_tromso, data_oslo], axis=0)

# %%
# replace dd.mm.yyyy to date format
data["date"] = pd.to_datetime(list(data["date"]), format="%d.%m.%Y")

# we are here only interested in the range december to may
data = data[(data["date"] > "2022-12-01") & (data["date"] < "2023-05-01")]

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    column="name",
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
from PIL import Image
from IPython.display import display
img = Image.open('snow_depth_1.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x395>

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    color="max temperature",
    column="name",
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
from PIL import Image
from IPython.display import display
img = Image.open('snow_depth.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=786x395>

# %%
alt.Chart(data).mark_bar().encode(
    x="date",
    y="snow depth",
    color=alt.Color("max temperature").scale(scheme="plasma"),
    column="name",
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %%
from PIL import Image
from IPython.display import display
img = Image.open('visualization.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=786x395>
